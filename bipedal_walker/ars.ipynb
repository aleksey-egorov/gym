# %%
import os
import numpy as np
import gym
from gym import wrappers
# import pybullet_envs

ENV_NAME = 'BipedalWalker-v2'
# ENV_NAME = 'HalfCheetahBulletEnv-v0'

# %%
class Hp():
    # Hyperparameters
    def __init__(self,
                 nb_steps=30000,
                 episode_length=2000,
                 learning_rate=0.02,
                 num_deltas=16,
                 num_best_deltas=16,
                 noise=0.03,
                 seed=1,
                 env_name='BipedalWalker-v2',
                 record_every=100):

        self.nb_steps = nb_steps
        self.episode_length = episode_length
        self.learning_rate = learning_rate
        self.num_deltas = num_deltas
        self.num_best_deltas = num_best_deltas
        assert self.num_best_deltas <= self.num_deltas
        self.noise = noise
        self.seed = seed
        self.env_name = env_name
        self.record_every = record_every


class Normalizer():
    # Normalizes the inputs
    def __init__(self, nb_inputs):
        self.n = np.zeros(nb_inputs)
        self.mean = np.zeros(nb_inputs)
        self.mean_diff = np.zeros(nb_inputs)
        self.var = np.zeros(nb_inputs)

    def observe(self, x):
        self.n += 1.0
        last_mean = self.mean.copy()
        self.mean += (x - self.mean) / self.n
        self.mean_diff += (x - last_mean) * (x - self.mean)
        self.var = (self.mean_diff / self.n).clip(min = 1e-2)

    def normalize(self, inputs):
        obs_mean = self.mean
        obs_std = np.sqrt(self.var)
        return (inputs - obs_mean) / obs_std


class Policy():
    def __init__(self, input_size, output_size, hp):
        self.theta = np.zeros((output_size, input_size))
        self.hp = hp

    def evaluate(self, input, delta = None, direction = None):
        if direction is None:
            return self.theta.dot(input)
        elif direction == "+":
            return (self.theta + self.hp.noise * delta).dot(input)
        elif direction == "-":
            return (self.theta - self.hp.noise * delta).dot(input)

    def sample_deltas(self):
        return [np.random.randn(*self.theta.shape) for _ in range(self.hp.num_deltas)]

    def update(self, rollouts, sigma_rewards):
        # sigma_rewards is the standard deviation of the rewards
        step = np.zeros(self.theta.shape)
        for r_pos, r_neg, delta in rollouts:
            step += (r_pos - r_neg) * delta
        self.theta += self.hp.learning_rate / (self.hp.num_best_deltas * sigma_rewards) * step


class ArsTrainer():
    def __init__(self,
                 hp=None,
                 input_size=None,
                 output_size=None,
                 normalizer=None,
                 policy=None,
                 monitor_dir=None):

        self.hp = hp or Hp()
        np.random.seed(self.hp.seed)
        self.env = gym.make(self.hp.env_name)
        if monitor_dir is not None:
            should_record = lambda i: self.record_video
            self.env = wrappers.Monitor(self.env, monitor_dir, video_callable=should_record, force=True)
        self.hp.episode_length = self.env.spec.timestep_limit or self.hp.episode_length
        self.input_size = input_size or self.env.observation_space.shape[0]
        self.output_size = output_size or self.env.action_space.shape[0]
        self.normalizer = normalizer or Normalizer(self.input_size)
        self.policy = policy or Policy(self.input_size, self.output_size, self.hp)
        self.record_video = False
        self.rewards_list = []
        self.log_interval = 10

    # Explore the policy on one specific direction and over one episode
    def explore(self, direction=None, delta=None):
        state = self.env.reset()
        done = False
        num_plays = 0.0
        sum_rewards = 0.0
        while not done and num_plays < self.hp.episode_length:
            self.normalizer.observe(state)
            state = self.normalizer.normalize(state)
            action = self.policy.evaluate(state, delta, direction)
            state, reward, done, _ = self.env.step(action)
            reward = max(min(reward, 1), -1)
            sum_rewards += reward
            num_plays += 1
        return sum_rewards

    def train(self):
        for step in range(self.hp.nb_steps):
            # initialize the random noise deltas and the positive/negative rewards
            deltas = self.policy.sample_deltas()
            positive_rewards = [0] * self.hp.num_deltas
            negative_rewards = [0] * self.hp.num_deltas

            # play an episode each with positive deltas and negative deltas, collect rewards
            for k in range(self.hp.num_deltas):
                positive_rewards[k] = self.explore(direction="+", delta=deltas[k])
                negative_rewards[k] = self.explore(direction="-", delta=deltas[k])
                
            # Compute the standard deviation of all rewards
            sigma_rewards = np.array(positive_rewards + negative_rewards).std()

            # Sort the rollouts by the max(r_pos, r_neg) and select the deltas with best rewards
            scores = {k:max(r_pos, r_neg) for k,(r_pos,r_neg) in enumerate(zip(positive_rewards, negative_rewards))}
            order = sorted(scores.keys(), key = lambda x:scores[x], reverse = True)[:self.hp.num_best_deltas]
            rollouts = [(positive_rewards[k], negative_rewards[k], deltas[k]) for k in order]

            # Update the policy
            self.policy.update(rollouts, sigma_rewards)
            
            
            # Only record video during evaluation, every n steps
            if step % self.hp.record_every == 0:
                self.record_video = True
            # Play an episode with the new weights and print the score
            reward_evaluation = self.explore()
            
            self.rewards_list.append(reward_evaluation)
            avg_reward = np.mean(self.rewards_list[-100:])
            
            if step % self.log_interval == 0:
                print('Step: {}  reward: {:4.2f} avg_reward: {:4.2f}  sigma: {:4.2f}  video: {}'.format(step, reward_evaluation, avg_reward, sigma_rewards, self.record_video))
                
            self.record_video = False
            
            # if avg reward > 300 then save and stop traning:
            if avg_reward >= self.env.spec.reward_threshold: 
                print("########## Solved! ###########")                
                
                self.record_video = True                
                reward_evaluation = self.explore()
                print("Video recorded") 
                break
            


def mkdir(base, name):
    path = os.path.join(base, name)
    if not os.path.exists(path):
        os.makedirs(path)
    return path

# Main code
videos_dir = mkdir('.', 'videos')
monitor_dir = mkdir(videos_dir, ENV_NAME)
hp = Hp(seed=1946, env_name=ENV_NAME)
trainer = ArsTrainer(hp=hp, monitor_dir=monitor_dir)
trainer.train()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Step: 0  reward: 6.73 avg_reward: 6.73  sigma: 8.99  video: True
# Step: 10  reward: 4.36 avg_reward: 5.29  sigma: 9.85  video: False
# Step: 20  reward: 4.89 avg_reward: 4.56  sigma: 1.61  video: False
# Step: 30  reward: 2.93 avg_reward: 4.26  sigma: 9.32  video: False
# Step: 40  reward: 2.90 avg_reward: 4.12  sigma: 3.53  video: False
# Step: 50  reward: 3.71 avg_reward: 4.10  sigma: 2.25  video: False
# Step: 60  reward: 2.93 avg_reward: 4.06  sigma: 6.16  video: False
# Step: 70  reward: 3.10 avg_reward: 4.02  sigma: 4.42  video: False
# Step: 80  reward: 4.50 avg_reward: 4.02  sigma: 9.18  video: False
# Step: 90  reward: 4.53 avg_reward: 4.10  sigma: 3.79  video: False
# Step: 100  reward: 4.49 avg_reward: 4.14  sigma: 0.72  video: True
# Step: 110  reward: 4.72 avg_reward: 4.10  sigma: 1.01  video: False
# Step: 120  reward: 4.88 avg_reward: 4.22  sigma: 3.24  video: False
# Step: 130  reward: 4.72 avg_reward: 4.34  sigma: 3.95  video: False
# Step: 140  reward: 5.09 avg_reward: 4.47  sigma: 1.12  video: False
# Step: 150  reward: 5.12 avg_reward: 4.59  sigma: 8.33  video: False
# Step: 160  reward: 5.70 avg_reward: 4.74  sigma: 4.60  video: False
# Step: 170  reward: 9.12 avg_reward: 4.99  sigma: 5.86  video: False
# Step: 180  reward: 13.53 avg_reward: 5.86  sigma: 6.61  video: False
# Step: 190  reward: 12.67 avg_reward: 6.70  sigma: 9.35  video: False
# Step: 200  reward: 11.84 avg_reward: 7.50  sigma: 6.04  video: True
# Step: 210  reward: 12.45 avg_reward: 8.34  sigma: 2.37  video: False
# Step: 220  reward: 13.49 avg_reward: 9.24  sigma: 10.34  video: False
# Step: 230  reward: 13.95 avg_reward: 10.17  sigma: 7.97  video: False
# Step: 240  reward: 14.65 avg_reward: 11.05  sigma: 4.39  video: False
# Step: 250  reward: 81.65 avg_reward: 13.83  sigma: 30.17  video: False
# Step: 260  reward: 22.74 avg_reward: 22.36  sigma: 42.18  video: False
# Step: 270  reward: 146.59 avg_reward: 35.43  sigma: 52.84  video: False
# Step: 280  reward: 27.55 avg_reward: 45.27  sigma: 51.87  video: False
# Step: 290  reward: 96.96 avg_reward: 58.09  sigma: 55.66  video: False
# Step: 300  reward: 164.33 avg_reward: 71.94  sigma: 47.70  video: True
# Step: 310  reward: 157.75 avg_reward: 87.09  sigma: 60.15  video: False
# Step: 320  reward: 162.31 avg_reward: 100.79  sigma: 42.69  video: False
# Step: 330  reward: 169.12 avg_reward: 115.11  sigma: 56.03  video: False
# Step: 340  reward: 45.47 avg_reward: 129.40  sigma: 46.37  video: False
# Step: 350  reward: 168.69 avg_reward: 142.64  sigma: 58.62  video: False
# Step: 360  reward: 174.76 avg_reward: 150.29  sigma: 50.94  video: False
# Step: 370  reward: 157.29 avg_reward: 152.83  sigma: 44.97  video: False
# Step: 380  reward: 165.41 avg_reward: 157.13  sigma: 42.50  video: False
# Step: 390  reward: 187.54 avg_reward: 160.59  sigma: 54.18  video: False
# Step: 400  reward: 190.77 avg_reward: 164.28  sigma: 53.92  video: True
# Step: 410  reward: 183.93 avg_reward: 165.35  sigma: 51.66  video: False
# Step: 420  reward: 202.38 avg_reward: 170.08  sigma: 67.82  video: False
# Step: 430  reward: 199.24 avg_reward: 174.53  sigma: 68.20  video: False
# Step: 440  reward: 196.96 avg_reward: 177.98  sigma: 46.57  video: False
# Step: 450  reward: 210.75 avg_reward: 181.83  sigma: 52.13  video: False
# Step: 460  reward: 198.43 avg_reward: 181.66  sigma: 54.20  video: False
# Step: 470  reward: 230.28 avg_reward: 186.52  sigma: 60.80  video: False
# Step: 480  reward: 220.75 avg_reward: 192.80  sigma: 57.74  video: False
# Step: 490  reward: 214.18 avg_reward: 196.34  sigma: 52.29  video: False
# Step: 500  reward: 215.31 avg_reward: 198.13  sigma: 43.52  video: True
# Step: 510  reward: 211.07 avg_reward: 201.33  sigma: 49.73  video: False
# Step: 520  reward: 102.10 avg_reward: 200.65  sigma: 50.63  video: False
# Step: 530  reward: 208.86 avg_reward: 199.33  sigma: 47.47  video: False
# Step: 540  reward: 207.07 avg_reward: 199.03  sigma: 29.63  video: False
# Step: 550  reward: 220.98 avg_reward: 199.70  sigma: 61.57  video: False
# Step: 560  reward: 215.18 avg_reward: 204.01  sigma: 42.20  video: False
# Step: 570  reward: 191.28 avg_reward: 203.57  sigma: 40.62  video: False
# Step: 580  reward: 215.79 avg_reward: 202.57  sigma: 27.54  video: False
# Step: 590  reward: 216.89 avg_reward: 202.20  sigma: 30.33  video: False
# Step: 600  reward: 212.39 avg_reward: 203.25  sigma: 34.94  video: True
# Step: 610  reward: 223.66 avg_reward: 203.81  sigma: 37.26  video: False
# Step: 620  reward: 225.50 avg_reward: 207.07  sigma: 28.56  video: False
# Step: 630  reward: 222.82 avg_reward: 210.64  sigma: 32.70  video: False
# Step: 640  reward: 221.78 avg_reward: 214.09  sigma: 40.90  video: False
# Step: 650  reward: 226.68 avg_reward: 214.62  sigma: 60.26  video: False
# Step: 660  reward: 219.14 avg_reward: 216.45  sigma: 22.37  video: False
# Step: 670  reward: 225.39 avg_reward: 218.48  sigma: 31.75  video: False
# Step: 680  reward: 221.14 avg_reward: 219.98  sigma: 24.36  video: False
# Step: 690  reward: 228.58 avg_reward: 222.05  sigma: 40.87  video: False
# Step: 700  reward: 232.11 avg_reward: 223.36  sigma: 45.68  video: True
# Step: 710  reward: 214.88 avg_reward: 224.25  sigma: 44.97  video: False
# Step: 720  reward: 234.92 avg_reward: 225.64  sigma: 61.50  video: False
# Step: 730  reward: 231.69 avg_reward: 223.56  sigma: 38.33  video: False
# Step: 740  reward: 234.77 avg_reward: 223.52  sigma: 37.69  video: False
# Step: 750  reward: 224.44 avg_reward: 225.07  sigma: 39.50  video: False
# Step: 760  reward: 228.66 avg_reward: 225.64  sigma: 46.53  video: False
# Step: 770  reward: 241.12 avg_reward: 226.60  sigma: 46.48  video: False
# Step: 780  reward: 238.74 avg_reward: 228.03  sigma: 59.65  video: False
# Step: 790  reward: 231.30 avg_reward: 227.55  sigma: 55.91  video: False
# Step: 800  reward: 232.29 avg_reward: 225.57  sigma: 44.69  video: True
# Step: 810  reward: 248.46 avg_reward: 226.56  sigma: 20.87  video: False
# Step: 820  reward: 244.05 avg_reward: 226.23  sigma: 27.04  video: False
# Step: 830  reward: 243.09 avg_reward: 229.13  sigma: 26.16  video: False
# Step: 840  reward: 240.86 avg_reward: 230.61  sigma: 46.44  video: False
# Step: 850  reward: 234.79 avg_reward: 231.44  sigma: 66.47  video: False
# Step: 860  reward: 228.21 avg_reward: 230.85  sigma: 63.41  video: False
# Step: 870  reward: 236.81 avg_reward: 230.82  sigma: 59.44  video: False
# Step: 880  reward: 241.52 avg_reward: 231.34  sigma: 55.10  video: False
# Step: 890  reward: 247.68 avg_reward: 233.55  sigma: 51.12  video: False
# Step: 900  reward: 250.95 avg_reward: 237.53  sigma: 67.26  video: True
# Step: 910  reward: 245.49 avg_reward: 239.04  sigma: 48.59  video: False
# Step: 920  reward: 244.29 avg_reward: 240.15  sigma: 63.48  video: False
# Step: 930  reward: 241.51 avg_reward: 241.10  sigma: 20.00  video: False
# Step: 940  reward: 239.44 avg_reward: 240.88  sigma: 67.71  video: False
# Step: 950  reward: 237.35 avg_reward: 241.83  sigma: 48.49  video: False
# Step: 960  reward: 259.22 avg_reward: 243.89  sigma: 60.22  video: False
# Step: 970  reward: 261.52 avg_reward: 245.53  sigma: 35.74  video: False
# Step: 980  reward: 259.82 avg_reward: 246.84  sigma: 59.10  video: False
# Step: 990  reward: 250.85 avg_reward: 247.87  sigma: 37.98  video: False
# Step: 1000  reward: 248.95 avg_reward: 248.07  sigma: 61.66  video: True
# Step: 1010  reward: 273.20 avg_reward: 248.61  sigma: 22.04  video: False
# Step: 1020  reward: 255.82 avg_reward: 247.86  sigma: 62.15  video: False
# Step: 1030  reward: 271.88 avg_reward: 249.47  sigma: 47.28  video: False
# Step: 1040  reward: 263.39 avg_reward: 252.42  sigma: 82.59  video: False
# Step: 1050  reward: 265.51 avg_reward: 253.78  sigma: 74.62  video: False
# Step: 1060  reward: 264.26 avg_reward: 255.10  sigma: 70.78  video: False
# Step: 1070  reward: 269.05 avg_reward: 256.36  sigma: 13.82  video: False
# Step: 1080  reward: 262.50 avg_reward: 257.58  sigma: 32.38  video: False
# Step: 1090  reward: 266.58 avg_reward: 258.28  sigma: 25.63  video: False
# Step: 1100  reward: 265.61 avg_reward: 259.50  sigma: 28.05  video: True
# Step: 1110  reward: 265.21 avg_reward: 259.95  sigma: 36.40  video: False
# Step: 1120  reward: 253.60 avg_reward: 260.42  sigma: 38.07  video: False
# Step: 1130  reward: 276.03 avg_reward: 257.41  sigma: 11.95  video: False
# Step: 1140  reward: 264.73 avg_reward: 257.49  sigma: 54.86  video: False
# Step: 1150  reward: 262.90 avg_reward: 257.74  sigma: 61.79  video: False
# Step: 1160  reward: 276.69 avg_reward: 258.76  sigma: 85.88  video: False
# Step: 1170  reward: 274.43 avg_reward: 258.89  sigma: 17.97  video: False
# Step: 1180  reward: 277.19 avg_reward: 260.09  sigma: 54.02  video: False
# Step: 1190  reward: 280.97 avg_reward: 261.63  sigma: 62.42  video: False
# Step: 1200  reward: 285.58 avg_reward: 261.04  sigma: 49.89  video: True
# Step: 1210  reward: 283.73 avg_reward: 263.02  sigma: 13.17  video: False
# Step: 1220  reward: 285.50 avg_reward: 266.61  sigma: 59.41  video: False
# Step: 1230  reward: 272.34 avg_reward: 270.35  sigma: 27.20  video: False
# Step: 1240  reward: 283.70 avg_reward: 272.27  sigma: 64.19  video: False
# Step: 1250  reward: 293.72 avg_reward: 274.04  sigma: 38.82  video: False
# Step: 1260  reward: 277.72 avg_reward: 275.41  sigma: 70.17  video: False
# Step: 1270  reward: 291.52 avg_reward: 277.67  sigma: 37.83  video: False
# Step: 1280  reward: 293.72 avg_reward: 278.90  sigma: 61.62  video: False
# Step: 1290  reward: 290.00 avg_reward: 280.10  sigma: 25.10  video: False
# Step: 1300  reward: 290.85 avg_reward: 283.22  sigma: 24.96  video: True
# Step: 1310  reward: 293.80 avg_reward: 284.82  sigma: 36.32  video: False
# Step: 1320  reward: 291.27 avg_reward: 286.00  sigma: 34.34  video: False
# Step: 1330  reward: 291.05 avg_reward: 288.22  sigma: 26.38  video: False
# Step: 1340  reward: 294.42 avg_reward: 289.18  sigma: 11.50  video: False
# Step: 1350  reward: 295.90 avg_reward: 290.43  sigma: 54.00  video: False
# Step: 1360  reward: 297.65 avg_reward: 291.59  sigma: 28.99  video: False
# Step: 1370  reward: 299.48 avg_reward: 292.61  sigma: 35.93  video: False
# Step: 1380  reward: 300.95 avg_reward: 293.39  sigma: 40.74  video: False
# Step: 1390  reward: 299.55 avg_reward: 294.26  sigma: 73.02  video: False
# Step: 1400  reward: 297.31 avg_reward: 295.21  sigma: 34.62  video: True
# Step: 1410  reward: 303.23 avg_reward: 296.07  sigma: 85.18  video: False
# Step: 1420  reward: 302.16 avg_reward: 297.23  sigma: 82.71  video: False
# Step: 1430  reward: 305.78 avg_reward: 298.68  sigma: 11.58  video: False
# Step: 1440  reward: 304.57 avg_reward: 299.82  sigma: 28.02  video: False
# ########## Solved! ###########
# Video recorded
