# %%
import argparse
import gym
import numpy as np
from itertools import count
from collections import namedtuple

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

args = {
    'gamma': 0.99,
    'render': True,
    'log_interval': 10
}

env = gym.make('MountainCar-v0')
#env.seed(args['seed'])
#torch.manual_seed(args['seed'])
episodes = 10000
print("action_space={}".format(env.action_space))
print("obs_space={}".format(env.observation_space))

SavedAction = namedtuple('SavedAction', ['log_prob', 'value'])


class Policy(nn.Module):
    def __init__(self):
        super(Policy, self).__init__()
        self.affine1 = nn.Linear(2, 128)
        self.action_head = nn.Linear(128, 3)
        self.value_head = nn.Linear(128, 1)

        self.saved_actions = []
        self.rewards = []

    def forward(self, x):
        x = F.relu(self.affine1(x))
        action_scores = self.action_head(x)
        state_values = self.value_head(x)
        return F.softmax(action_scores, dim=-1), state_values


model = Policy()
optimizer = optim.Adam(model.parameters(), lr=0.0001)
eps = np.finfo(np.float32).eps.item()


def select_action(state):
    state = torch.from_numpy(state).float()
    probs, state_value = model(state)
    m = Categorical(probs)
    action = m.sample()
    model.saved_actions.append(SavedAction(m.log_prob(action), state_value))
    return action.item()


def finish_episode():
    R = 0
    saved_actions = model.saved_actions
    policy_losses = []
    value_losses = []
    rewards = []
    for r in model.rewards[::-1]:
        R = r + args['gamma'] * R
        rewards.insert(0, R)
    rewards = torch.tensor(rewards)
    rewards = (rewards - rewards.mean()) / (rewards.std() + eps)
    for (log_prob, value), r in zip(saved_actions, rewards):
        reward = r - value.item()
        policy_losses.append(-log_prob * reward)
        value_losses.append(F.smooth_l1_loss(value, torch.tensor([r])))
    optimizer.zero_grad()
    loss = torch.stack(policy_losses).sum() + torch.stack(value_losses).sum()
    loss.backward()
    optimizer.step()
    del model.rewards[:]
    del model.saved_actions[:]


def main():    
    for i_episode in range(episodes):
        running_reward = 0
        heights = []
        velocities = []
        state = env.reset()
        for t in range(10000):  # Don't infinite loop while learning
            action = select_action(state)            
            state, reward, done, _ = env.step(action)            
            if args['render']:
                env.render()
            model.rewards.append(reward)            
            running_reward += reward
            heights.append(state[0])
            velocities.append(state[1])
            if done:
                break
                
        #avg_height = 1 + np.mean(np.array(heights))         
        max_height = np.abs(np.max(np.array(heights))) 
        max_velocity = np.abs(np.max(np.array(velocities))) 
        running_reward = running_reward + max_height * 10 + max_velocity * 10 # + avg_velocity * 10
        
        finish_episode()
        if i_episode % args['log_interval'] == 0:
            print('Episode {}\tLast length: {:5d}\t Reward: {:.2f} Max height: {:.2f} Max velocity: {:.6f}'.format(
                i_episode, t, running_reward, max_height, max_velocity))
        if running_reward > env.spec.reward_threshold:
            print("Solved! Running reward is now {} and "
                  "the last episode runs to {} time steps!".format(running_reward, t))
            break

print("threshold={} \n".format(env.spec.reward_threshold))
main()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# action_space=Discrete(3)
# obs_space=Box(2,)
# threshold=-110.0
#
# Episode 0	Last length:   199	 Reward: -196.48 Max height: 0.34 Max velocity: 0.016668
# Episode 10	Last length:   199	 Reward: -195.44 Max height: 0.45 Max velocity: 0.007596
# Episode 20	Last length:   199	 Reward: -195.26 Max height: 0.47 Max velocity: 0.005445
# Episode 30	Last length:   199	 Reward: -196.47 Max height: 0.33 Max velocity: 0.019249
# Episode 40	Last length:   199	 Reward: -195.40 Max height: 0.45 Max velocity: 0.011185
# Episode 50	Last length:   199	 Reward: -196.95 Max height: 0.29 Max velocity: 0.019837
# Episode 60	Last length:   199	 Reward: -196.09 Max height: 0.38 Max velocity: 0.010786
# Episode 70	Last length:   199	 Reward: -195.52 Max height: 0.44 Max velocity: 0.008378
# Episode 80	Last length:   199	 Reward: -196.03 Max height: 0.39 Max velocity: 0.011483
# Episode 90	Last length:   199	 Reward: -195.40 Max height: 0.45 Max velocity: 0.009988
# Episode 100	Last length:   199	 Reward: -195.68 Max height: 0.42 Max velocity: 0.016487
# Episode 110	Last length:   199	 Reward: -195.26 Max height: 0.47 Max velocity: 0.006328
# Episode 120	Last length:   199	 Reward: -195.78 Max height: 0.41 Max velocity: 0.010541
# Episode 130	Last length:   199	 Reward: -195.75 Max height: 0.41 Max velocity: 0.010929
# Episode 140	Last length:   199	 Reward: -195.61 Max height: 0.43 Max velocity: 0.007163
# Episode 150	Last length:   199	 Reward: -195.77 Max height: 0.41 Max velocity: 0.013726
# Episode 160	Last length:   199	 Reward: -195.88 Max height: 0.39 Max velocity: 0.017972
# Episode 170	Last length:   199	 Reward: -195.37 Max height: 0.46 Max velocity: 0.006736
# Episode 180	Last length:   199	 Reward: -195.81 Max height: 0.41 Max velocity: 0.012251
# Episode 190	Last length:   199	 Reward: -195.72 Max height: 0.42 Max velocity: 0.008621
# Episode 200	Last length:   199	 Reward: -197.55 Max height: 0.22 Max velocity: 0.020688
# Episode 210	Last length:   199	 Reward: -195.80 Max height: 0.40 Max velocity: 0.016671
# Episode 220	Last length:   199	 Reward: -195.33 Max height: 0.46 Max velocity: 0.009318
# Episode 230	Last length:   199	 Reward: -196.11 Max height: 0.37 Max velocity: 0.016822
# Episode 240	Last length:   199	 Reward: -197.41 Max height: 0.24 Max velocity: 0.022462
# Episode 250	Last length:   199	 Reward: -195.86 Max height: 0.40 Max velocity: 0.012524
# Episode 260	Last length:   199	 Reward: -195.87 Max height: 0.40 Max velocity: 0.014757
# Episode 270	Last length:   199	 Reward: -195.28 Max height: 0.47 Max velocity: 0.005789
# Episode 280	Last length:   199	 Reward: -196.74 Max height: 0.30 Max velocity: 0.021422
# Episode 290	Last length:   199	 Reward: -196.05 Max height: 0.38 Max velocity: 0.015595
# Episode 300	Last length:   199	 Reward: -197.34 Max height: 0.24 Max velocity: 0.024875
# Episode 310	Last length:   199	 Reward: -196.52 Max height: 0.33 Max velocity: 0.016349
# Episode 320	Last length:   199	 Reward: -195.49 Max height: 0.44 Max velocity: 0.005860
# Episode 330	Last length:   199	 Reward: -197.05 Max height: 0.28 Max velocity: 0.019517
# Episode 340	Last length:   199	 Reward: -196.01 Max height: 0.39 Max velocity: 0.008711
# Episode 350	Last length:   199	 Reward: -196.49 Max height: 0.34 Max velocity: 0.009989
# Episode 360	Last length:   199	 Reward: -196.64 Max height: 0.32 Max velocity: 0.014099
# Episode 370	Last length:   199	 Reward: -195.77 Max height: 0.42 Max velocity: 0.007575
# Episode 380	Last length:   199	 Reward: -196.38 Max height: 0.35 Max velocity: 0.014753
# Episode 390	Last length:   199	 Reward: -195.91 Max height: 0.40 Max velocity: 0.013724
# Episode 400	Last length:   199	 Reward: -196.47 Max height: 0.34 Max velocity: 0.018224
# Episode 410	Last length:   199	 Reward: -195.33 Max height: 0.46 Max velocity: 0.005737
# Episode 420	Last length:   199	 Reward: -195.32 Max height: 0.46 Max velocity: 0.009010
# Episode 430	Last length:   199	 Reward: -195.40 Max height: 0.45 Max velocity: 0.014206
# Episode 440	Last length:   199	 Reward: -195.43 Max height: 0.44 Max velocity: 0.016689
# Episode 450	Last length:   199	 Reward: -196.08 Max height: 0.38 Max velocity: 0.008460
# Episode 460	Last length:   199	 Reward: -197.09 Max height: 0.27 Max velocity: 0.016606
# Episode 470	Last length:   199	 Reward: -195.90 Max height: 0.40 Max velocity: 0.009879
# Episode 480	Last length:   199	 Reward: -196.11 Max height: 0.38 Max velocity: 0.010634
# Episode 490	Last length:   199	 Reward: -196.37 Max height: 0.35 Max velocity: 0.013789
# Episode 500	Last length:   199	 Reward: -196.04 Max height: 0.38 Max velocity: 0.011288
# Episode 510	Last length:   199	 Reward: -196.16 Max height: 0.37 Max velocity: 0.012653
# Episode 520	Last length:   199	 Reward: -195.41 Max height: 0.45 Max velocity: 0.009737
# Episode 530	Last length:   199	 Reward: -195.74 Max height: 0.41 Max velocity: 0.011847
# Episode 540	Last length:   199	 Reward: -196.40 Max height: 0.34 Max velocity: 0.016629
# Episode 550	Last length:   199	 Reward: -196.05 Max height: 0.38 Max velocity: 0.014018
# Episode 560	Last length:   199	 Reward: -196.35 Max height: 0.34 Max velocity: 0.020959
# Episode 570	Last length:   199	 Reward: -195.66 Max height: 0.42 Max velocity: 0.010243
# Episode 580	Last length:   199	 Reward: -196.41 Max height: 0.35 Max velocity: 0.010950
# Episode 590	Last length:   199	 Reward: -195.97 Max height: 0.39 Max velocity: 0.012623
# Episode 600	Last length:   199	 Reward: -195.74 Max height: 0.41 Max velocity: 0.011983
# Episode 610	Last length:   199	 Reward: -196.62 Max height: 0.33 Max velocity: 0.012421
# Episode 620	Last length:   199	 Reward: -195.41 Max height: 0.45 Max velocity: 0.006869
# Episode 630	Last length:   199	 Reward: -196.31 Max height: 0.35 Max velocity: 0.016380
# Episode 640	Last length:   199	 Reward: -195.72 Max height: 0.42 Max velocity: 0.009202
# Episode 650	Last length:   199	 Reward: -195.64 Max height: 0.43 Max velocity: 0.008697
# Episode 660	Last length:   199	 Reward: -196.78 Max height: 0.31 Max velocity: 0.016128
# Episode 670	Last length:   199	 Reward: -195.61 Max height: 0.43 Max velocity: 0.008839
# Episode 680	Last length:   199	 Reward: -196.29 Max height: 0.35 Max velocity: 0.015921
# Episode 690	Last length:   199	 Reward: -196.62 Max height: 0.32 Max velocity: 0.018614
# Episode 700	Last length:   199	 Reward: -195.78 Max height: 0.41 Max velocity: 0.009308
# Episode 710	Last length:   199	 Reward: -195.75 Max height: 0.42 Max velocity: 0.008936
# Episode 720	Last length:   199	 Reward: -195.91 Max height: 0.40 Max velocity: 0.012659
# Episode 730	Last length:   199	 Reward: -196.04 Max height: 0.38 Max velocity: 0.011048
# Episode 740	Last length:   199	 Reward: -196.31 Max height: 0.35 Max velocity: 0.023753
# Episode 750	Last length:   199	 Reward: -196.30 Max height: 0.36 Max velocity: 0.013134
# Episode 760	Last length:   199	 Reward: -195.82 Max height: 0.41 Max velocity: 0.009584
# Episode 770	Last length:   199	 Reward: -195.23 Max height: 0.47 Max velocity: 0.006430
# Episode 780	Last length:   199	 Reward: -196.02 Max height: 0.38 Max velocity: 0.016196
# Episode 790	Last length:   199	 Reward: -196.39 Max height: 0.35 Max velocity: 0.014797
# Episode 800	Last length:   199	 Reward: -196.32 Max height: 0.35 Max velocity: 0.015333
# Episode 810	Last length:   199	 Reward: -196.18 Max height: 0.36 Max velocity: 0.018402
# Episode 820	Last length:   199	 Reward: -195.80 Max height: 0.41 Max velocity: 0.007207
# Episode 830	Last length:   199	 Reward: -196.34 Max height: 0.35 Max velocity: 0.014854
# Episode 840	Last length:   199	 Reward: -196.56 Max height: 0.33 Max velocity: 0.018105
# Episode 850	Last length:   199	 Reward: -195.58 Max height: 0.43 Max velocity: 0.007749
# Episode 860	Last length:   199	 Reward: -196.17 Max height: 0.37 Max velocity: 0.009821
# Episode 870	Last length:   199	 Reward: -197.29 Max height: 0.25 Max velocity: 0.020315
# Episode 880	Last length:   199	 Reward: -196.21 Max height: 0.36 Max velocity: 0.016733
# Episode 890	Last length:   199	 Reward: -196.98 Max height: 0.28 Max velocity: 0.018640
# Episode 900	Last length:   199	 Reward: -195.82 Max height: 0.41 Max velocity: 0.010721
# Episode 910	Last length:   199	 Reward: -195.35 Max height: 0.46 Max velocity: 0.005941
# Episode 920	Last length:   199	 Reward: -196.82 Max height: 0.30 Max velocity: 0.016882
# Episode 930	Last length:   199	 Reward: -195.77 Max height: 0.41 Max velocity: 0.011138
# Episode 940	Last length:   199	 Reward: -196.09 Max height: 0.38 Max velocity: 0.012349
# Episode 950	Last length:   199	 Reward: -195.10 Max height: 0.48 Max velocity: 0.008210
# Episode 960	Last length:   199	 Reward: -196.35 Max height: 0.35 Max velocity: 0.011889
# Episode 970	Last length:   199	 Reward: -196.05 Max height: 0.38 Max velocity: 0.012038
# Episode 980	Last length:   199	 Reward: -195.26 Max height: 0.47 Max velocity: 0.003764
# Episode 990	Last length:   199	 Reward: -196.34 Max height: 0.35 Max velocity: 0.012804
# Episode 1000	Last length:   199	 Reward: -196.36 Max height: 0.35 Max velocity: 0.014936
# Episode 1010	Last length:   199	 Reward: -195.81 Max height: 0.41 Max velocity: 0.007414
# Episode 1020	Last length:   199	 Reward: -197.45 Max height: 0.23 Max velocity: 0.024253
# Episode 1030	Last length:   199	 Reward: -197.03 Max height: 0.28 Max velocity: 0.021811
# Episode 1040	Last length:   199	 Reward: -196.49 Max height: 0.32 Max velocity: 0.025917
# Episode 1050	Last length:   199	 Reward: -196.01 Max height: 0.39 Max velocity: 0.012874
# Episode 1060	Last length:   199	 Reward: -195.29 Max height: 0.47 Max velocity: 0.005232
# Episode 1070	Last length:   199	 Reward: -195.83 Max height: 0.41 Max velocity: 0.008942
# Episode 1080	Last length:   199	 Reward: -196.62 Max height: 0.32 Max velocity: 0.014702
# Episode 1090	Last length:   199	 Reward: -196.13 Max height: 0.38 Max velocity: 0.010383
# Episode 1100	Last length:   199	 Reward: -197.19 Max height: 0.26 Max velocity: 0.023629
# Episode 1110	Last length:   199	 Reward: -196.73 Max height: 0.31 Max velocity: 0.013635
# Episode 1120	Last length:   199	 Reward: -195.52 Max height: 0.44 Max velocity: 0.007962
# Episode 1130	Last length:   199	 Reward: -196.37 Max height: 0.35 Max velocity: 0.009970
# Episode 1140	Last length:   199	 Reward: -195.96 Max height: 0.39 Max velocity: 0.017137
# Episode 1150	Last length:   199	 Reward: -195.40 Max height: 0.45 Max velocity: 0.011228
# Episode 1160	Last length:   199	 Reward: -195.23 Max height: 0.47 Max velocity: 0.006500
# Episode 1170	Last length:   199	 Reward: -196.24 Max height: 0.36 Max velocity: 0.015345
# Episode 1180	Last length:   199	 Reward: -196.11 Max height: 0.38 Max velocity: 0.009872
# Episode 1190	Last length:   199	 Reward: -197.08 Max height: 0.27 Max velocity: 0.023094
# Episode 1200	Last length:   199	 Reward: -196.25 Max height: 0.36 Max velocity: 0.015162
# Episode 1210	Last length:   199	 Reward: -196.31 Max height: 0.36 Max velocity: 0.013454
# Episode 1220	Last length:   199	 Reward: -195.52 Max height: 0.44 Max velocity: 0.010480
# Episode 1230	Last length:   199	 Reward: -195.49 Max height: 0.44 Max velocity: 0.010159
# Episode 1240	Last length:   199	 Reward: -196.38 Max height: 0.35 Max velocity: 0.011898
# Episode 1250	Last length:   199	 Reward: -195.86 Max height: 0.41 Max velocity: 0.007579
# Episode 1260	Last length:   199	 Reward: -196.64 Max height: 0.32 Max velocity: 0.016805
# Episode 1270	Last length:   199	 Reward: -195.59 Max height: 0.43 Max velocity: 0.006327
# Episode 1280	Last length:   199	 Reward: -196.46 Max height: 0.34 Max velocity: 0.014943
# Episode 1290	Last length:   199	 Reward: -195.97 Max height: 0.40 Max velocity: 0.007355
# Episode 1300	Last length:   199	 Reward: -195.76 Max height: 0.41 Max velocity: 0.010479
# Episode 1310	Last length:   199	 Reward: -196.09 Max height: 0.38 Max velocity: 0.012351
# Episode 1320	Last length:   199	 Reward: -195.31 Max height: 0.46 Max velocity: 0.007785
# Episode 1330	Last length:   199	 Reward: -195.55 Max height: 0.43 Max velocity: 0.011168
# Episode 1340	Last length:   199	 Reward: -195.90 Max height: 0.40 Max velocity: 0.009999
# Episode 1350	Last length:   199	 Reward: -195.12 Max height: 0.48 Max velocity: 0.006158
# Episode 1360	Last length:   199	 Reward: -196.54 Max height: 0.33 Max velocity: 0.014023
# Episode 1370	Last length:   199	 Reward: -196.15 Max height: 0.37 Max velocity: 0.016030
# Episode 1380	Last length:   199	 Reward: -195.94 Max height: 0.39 Max velocity: 0.012540
# Episode 1390	Last length:   199	 Reward: -195.59 Max height: 0.43 Max velocity: 0.006356
# Episode 1400	Last length:   199	 Reward: -196.07 Max height: 0.38 Max velocity: 0.010673
# Episode 1410	Last length:   199	 Reward: -195.50 Max height: 0.44 Max velocity: 0.011095
# Episode 1420	Last length:   199	 Reward: -195.96 Max height: 0.39 Max velocity: 0.009689
# Episode 1430	Last length:   199	 Reward: -196.84 Max height: 0.29 Max velocity: 0.021897
# Episode 1440	Last length:   199	 Reward: -196.68 Max height: 0.31 Max velocity: 0.019948
# Episode 1450	Last length:   199	 Reward: -196.67 Max height: 0.31 Max velocity: 0.018645
# Episode 1460	Last length:   199	 Reward: -196.30 Max height: 0.36 Max velocity: 0.014201
# Episode 1470	Last length:   199	 Reward: -196.24 Max height: 0.36 Max velocity: 0.019600
# Episode 1480	Last length:   199	 Reward: -195.75 Max height: 0.41 Max velocity: 0.011088
# Episode 1490	Last length:   199	 Reward: -196.44 Max height: 0.34 Max velocity: 0.016317
# Episode 1500	Last length:   199	 Reward: -196.82 Max height: 0.30 Max velocity: 0.019939
# Episode 1510	Last length:   199	 Reward: -197.06 Max height: 0.27 Max velocity: 0.022630
# Episode 1520	Last length:   199	 Reward: -195.86 Max height: 0.40 Max velocity: 0.010671
# Episode 1530	Last length:   199	 Reward: -196.77 Max height: 0.30 Max velocity: 0.020897
# Episode 1540	Last length:   199	 Reward: -196.83 Max height: 0.30 Max velocity: 0.016638
# Episode 1550	Last length:   199	 Reward: -195.47 Max height: 0.45 Max velocity: 0.004991
# Episode 1560	Last length:   199	 Reward: -195.78 Max height: 0.41 Max velocity: 0.008393
# Episode 1570	Last length:   199	 Reward: -195.97 Max height: 0.40 Max velocity: 0.008218
# Episode 1580	Last length:   199	 Reward: -196.65 Max height: 0.32 Max velocity: 0.015293
# Episode 1590	Last length:   199	 Reward: -196.20 Max height: 0.37 Max velocity: 0.012653
# Episode 1600	Last length:   199	 Reward: -196.04 Max height: 0.38 Max velocity: 0.012368
# Episode 1610	Last length:   199	 Reward: -195.66 Max height: 0.42 Max velocity: 0.017417
# Episode 1620	Last length:   199	 Reward: -195.51 Max height: 0.44 Max velocity: 0.008197
# Episode 1630	Last length:   199	 Reward: -196.71 Max height: 0.31 Max velocity: 0.016263
# Episode 1640	Last length:   199	 Reward: -195.19 Max height: 0.47 Max velocity: 0.006463
# Episode 1650	Last length:   199	 Reward: -196.10 Max height: 0.38 Max velocity: 0.012979
# Episode 1660	Last length:   199	 Reward: -195.37 Max height: 0.45 Max velocity: 0.010635
# Episode 1670	Last length:   199	 Reward: -196.38 Max height: 0.35 Max velocity: 0.012109
# Episode 1680	Last length:   199	 Reward: -196.23 Max height: 0.36 Max velocity: 0.015402
# Episode 1690	Last length:   199	 Reward: -197.10 Max height: 0.27 Max velocity: 0.017685
# Episode 1700	Last length:   199	 Reward: -195.18 Max height: 0.47 Max velocity: 0.008161
# Episode 1710	Last length:   199	 Reward: -196.23 Max height: 0.37 Max velocity: 0.009849
# Episode 1720	Last length:   199	 Reward: -196.63 Max height: 0.31 Max velocity: 0.026352
# Episode 1730	Last length:   199	 Reward: -196.18 Max height: 0.37 Max velocity: 0.012696
# Episode 1740	Last length:   199	 Reward: -195.66 Max height: 0.43 Max velocity: 0.007371
# Episode 1750	Last length:   199	 Reward: -196.69 Max height: 0.31 Max velocity: 0.019775
# Episode 1760	Last length:   199	 Reward: -196.31 Max height: 0.35 Max velocity: 0.014162
# Episode 1770	Last length:   199	 Reward: -195.44 Max height: 0.45 Max velocity: 0.006834
# Episode 1780	Last length:   199	 Reward: -195.84 Max height: 0.40 Max velocity: 0.014018
# Episode 1790	Last length:   199	 Reward: -196.17 Max height: 0.37 Max velocity: 0.011721
# Episode 1800	Last length:   199	 Reward: -195.99 Max height: 0.39 Max velocity: 0.012212
# Episode 1810	Last length:   199	 Reward: -196.13 Max height: 0.38 Max velocity: 0.008788
# Episode 1820	Last length:   199	 Reward: -195.44 Max height: 0.45 Max velocity: 0.008554
# Episode 1830	Last length:   199	 Reward: -196.49 Max height: 0.34 Max velocity: 0.016183
# Episode 1840	Last length:   199	 Reward: -195.49 Max height: 0.45 Max velocity: 0.005538
# Episode 1850	Last length:   199	 Reward: -195.29 Max height: 0.47 Max velocity: 0.005238
# Episode 1860	Last length:   199	 Reward: -196.30 Max height: 0.36 Max velocity: 0.013973
# Episode 1870	Last length:   199	 Reward: -197.13 Max height: 0.27 Max velocity: 0.020451
# Episode 1880	Last length:   199	 Reward: -195.72 Max height: 0.42 Max velocity: 0.011284
# Episode 1890	Last length:   199	 Reward: -195.89 Max height: 0.40 Max velocity: 0.011846
# Episode 1900	Last length:   199	 Reward: -195.66 Max height: 0.42 Max velocity: 0.009838
# Episode 1910	Last length:   199	 Reward: -196.50 Max height: 0.33 Max velocity: 0.015857
# Episode 1920	Last length:   199	 Reward: -196.06 Max height: 0.38 Max velocity: 0.009880
# Episode 1930	Last length:   199	 Reward: -195.56 Max height: 0.44 Max velocity: 0.008894
# Episode 1940	Last length:   199	 Reward: -195.66 Max height: 0.42 Max velocity: 0.012345
# Episode 1950	Last length:   199	 Reward: -195.50 Max height: 0.44 Max velocity: 0.006208
# Episode 1960	Last length:   199	 Reward: -196.33 Max height: 0.35 Max velocity: 0.015101
# Episode 1970	Last length:   199	 Reward: -195.46 Max height: 0.45 Max velocity: 0.008005
# Episode 1980	Last length:   199	 Reward: -196.00 Max height: 0.39 Max velocity: 0.012079
# Episode 1990	Last length:   199	 Reward: -196.56 Max height: 0.33 Max velocity: 0.014583
# Episode 2000	Last length:   199	 Reward: -195.56 Max height: 0.43 Max velocity: 0.009553
# Episode 2010	Last length:   199	 Reward: -195.40 Max height: 0.45 Max velocity: 0.008000
# Episode 2020	Last length:   199	 Reward: -196.48 Max height: 0.34 Max velocity: 0.016276
# Episode 2030	Last length:   199	 Reward: -195.60 Max height: 0.43 Max velocity: 0.010941
# Episode 2040	Last length:   199	 Reward: -196.49 Max height: 0.34 Max velocity: 0.014465
# Episode 2050	Last length:   199	 Reward: -195.90 Max height: 0.40 Max velocity: 0.011783
# Episode 2060	Last length:   199	 Reward: -195.64 Max height: 0.43 Max velocity: 0.008019
# Episode 2070	Last length:   199	 Reward: -195.75 Max height: 0.41 Max velocity: 0.012998
# Episode 2080	Last length:   199	 Reward: -196.43 Max height: 0.34 Max velocity: 0.017457
# Episode 2090	Last length:   199	 Reward: -195.67 Max height: 0.42 Max velocity: 0.011540
# Episode 2100	Last length:   199	 Reward: -195.61 Max height: 0.42 Max velocity: 0.015480
# Episode 2110	Last length:   199	 Reward: -195.37 Max height: 0.46 Max velocity: 0.007869
# Episode 2120	Last length:   199	 Reward: -195.33 Max height: 0.46 Max velocity: 0.005566
# Episode 2130	Last length:   199	 Reward: -195.80 Max height: 0.41 Max velocity: 0.011068
# Episode 2140	Last length:   199	 Reward: -195.68 Max height: 0.42 Max velocity: 0.010185
# Episode 2150	Last length:   199	 Reward: -195.53 Max height: 0.44 Max velocity: 0.008611
# Episode 2160	Last length:   199	 Reward: -195.69 Max height: 0.41 Max velocity: 0.019122
# Episode 2170	Last length:   199	 Reward: -195.64 Max height: 0.43 Max velocity: 0.009138
# Episode 2180	Last length:   199	 Reward: -195.68 Max height: 0.42 Max velocity: 0.010860
# Episode 2190	Last length:   199	 Reward: -196.36 Max height: 0.35 Max velocity: 0.016660
# Episode 2200	Last length:   199	 Reward: -196.44 Max height: 0.34 Max velocity: 0.016117
# Episode 2210	Last length:   199	 Reward: -196.00 Max height: 0.39 Max velocity: 0.013651
# Episode 2220	Last length:   199	 Reward: -195.72 Max height: 0.42 Max velocity: 0.010746
# Episode 2230	Last length:   199	 Reward: -195.37 Max height: 0.45 Max velocity: 0.009648
# Episode 2240	Last length:   199	 Reward: -195.77 Max height: 0.42 Max velocity: 0.007553
# Episode 2250	Last length:   199	 Reward: -195.51 Max height: 0.44 Max velocity: 0.008208
# Episode 2260	Last length:   199	 Reward: -196.08 Max height: 0.38 Max velocity: 0.011853
# Episode 2270	Last length:   199	 Reward: -196.04 Max height: 0.38 Max velocity: 0.013851
# Episode 2280	Last length:   199	 Reward: -195.99 Max height: 0.39 Max velocity: 0.012823
# Episode 2290	Last length:   199	 Reward: -196.58 Max height: 0.32 Max velocity: 0.018038
# Episode 2300	Last length:   199	 Reward: -196.19 Max height: 0.37 Max velocity: 0.014695
# Episode 2310	Last length:   199	 Reward: -196.36 Max height: 0.35 Max velocity: 0.015577
# Episode 2320	Last length:   199	 Reward: -196.04 Max height: 0.38 Max velocity: 0.013006
# Episode 2330	Last length:   199	 Reward: -195.92 Max height: 0.40 Max velocity: 0.011857
# Episode 2340	Last length:   199	 Reward: -195.38 Max height: 0.45 Max velocity: 0.007849
# Episode 2350	Last length:   199	 Reward: -195.61 Max height: 0.43 Max velocity: 0.010515
# Episode 2360	Last length:   199	 Reward: -195.60 Max height: 0.43 Max velocity: 0.008325
# Episode 2370	Last length:   199	 Reward: -195.62 Max height: 0.43 Max velocity: 0.010070
# Episode 2380	Last length:   199	 Reward: -196.08 Max height: 0.38 Max velocity: 0.010433
# Episode 2390	Last length:   199	 Reward: -195.55 Max height: 0.44 Max velocity: 0.009072
# Episode 2400	Last length:   199	 Reward: -195.94 Max height: 0.39 Max velocity: 0.012640
# Episode 2410	Last length:   199	 Reward: -195.86 Max height: 0.40 Max velocity: 0.010026
# Episode 2420	Last length:   199	 Reward: -196.71 Max height: 0.31 Max velocity: 0.018322
# Episode 2430	Last length:   199	 Reward: -196.13 Max height: 0.37 Max velocity: 0.019461
# Episode 2440	Last length:   199	 Reward: -196.34 Max height: 0.35 Max velocity: 0.014798
# Episode 2450	Last length:   199	 Reward: -197.13 Max height: 0.26 Max velocity: 0.024264
# Episode 2460	Last length:   199	 Reward: -195.59 Max height: 0.43 Max velocity: 0.010024
# Episode 2470	Last length:   199	 Reward: -195.73 Max height: 0.42 Max velocity: 0.010192
# Episode 2480	Last length:   199	 Reward: -196.28 Max height: 0.35 Max velocity: 0.017510
# Episode 2490	Last length:   199	 Reward: -195.35 Max height: 0.46 Max velocity: 0.006768
# Episode 2500	Last length:   199	 Reward: -197.37 Max height: 0.24 Max velocity: 0.020963
# Episode 2510	Last length:   199	 Reward: -196.78 Max height: 0.31 Max velocity: 0.016465
# Episode 2520	Last length:   199	 Reward: -195.90 Max height: 0.40 Max velocity: 0.009537
# Episode 2530	Last length:   199	 Reward: -196.12 Max height: 0.37 Max velocity: 0.015486
# Episode 2540	Last length:   199	 Reward: -196.18 Max height: 0.37 Max velocity: 0.013619
# Episode 2550	Last length:   199	 Reward: -196.47 Max height: 0.34 Max velocity: 0.013989
# Episode 2560	Last length:   199	 Reward: -196.34 Max height: 0.35 Max velocity: 0.015299
# Episode 2570	Last length:   199	 Reward: -195.45 Max height: 0.44 Max velocity: 0.012849
# Episode 2580	Last length:   199	 Reward: -196.17 Max height: 0.37 Max velocity: 0.013312
# Episode 2590	Last length:   199	 Reward: -195.80 Max height: 0.41 Max velocity: 0.010321
# Episode 2600	Last length:   199	 Reward: -195.16 Max height: 0.48 Max velocity: 0.007916
# Episode 2610	Last length:   199	 Reward: -196.41 Max height: 0.34 Max velocity: 0.016780
# Episode 2620	Last length:   199	 Reward: -195.63 Max height: 0.43 Max velocity: 0.009683
# Episode 2630	Last length:   199	 Reward: -195.59 Max height: 0.43 Max velocity: 0.009099
# Episode 2640	Last length:   199	 Reward: -195.97 Max height: 0.39 Max velocity: 0.013278
# Episode 2650	Last length:   199	 Reward: -196.38 Max height: 0.35 Max velocity: 0.012452
# Episode 2660	Last length:   199	 Reward: -197.51 Max height: 0.22 Max velocity: 0.026322
# Episode 2670	Last length:   199	 Reward: -196.95 Max height: 0.29 Max velocity: 0.019572
# Episode 2680	Last length:   199	 Reward: -195.40 Max height: 0.45 Max velocity: 0.010603
# Episode 2690	Last length:   199	 Reward: -196.26 Max height: 0.36 Max velocity: 0.012567
# Episode 2700	Last length:   199	 Reward: -195.83 Max height: 0.41 Max velocity: 0.011594
# Episode 2710	Last length:   199	 Reward: -195.91 Max height: 0.40 Max velocity: 0.011492
# Episode 2720	Last length:   199	 Reward: -195.82 Max height: 0.41 Max velocity: 0.009570
# Episode 2730	Last length:   199	 Reward: -196.52 Max height: 0.33 Max velocity: 0.021064
# Episode 2740	Last length:   199	 Reward: -196.75 Max height: 0.30 Max velocity: 0.027091
# Episode 2750	Last length:   199	 Reward: -195.67 Max height: 0.42 Max velocity: 0.011950
# Episode 2760	Last length:   199	 Reward: -195.86 Max height: 0.40 Max velocity: 0.015661
# Episode 2770	Last length:   199	 Reward: -197.03 Max height: 0.27 Max velocity: 0.022364
# Episode 2780	Last length:   199	 Reward: -195.51 Max height: 0.44 Max velocity: 0.010329
# Episode 2790	Last length:   199	 Reward: -195.78 Max height: 0.41 Max velocity: 0.011806
# Episode 2800	Last length:   199	 Reward: -195.84 Max height: 0.41 Max velocity: 0.010071
# Episode 2810	Last length:   199	 Reward: -195.13 Max height: 0.48 Max velocity: 0.004930
# Episode 2820	Last length:   199	 Reward: -196.73 Max height: 0.30 Max velocity: 0.023919
# Episode 2830	Last length:   199	 Reward: -195.32 Max height: 0.46 Max velocity: 0.008806
# Episode 2840	Last length:   199	 Reward: -196.09 Max height: 0.38 Max velocity: 0.012742
# Episode 2850	Last length:   199	 Reward: -196.89 Max height: 0.29 Max velocity: 0.019140
# Episode 2860	Last length:   199	 Reward: -196.28 Max height: 0.36 Max velocity: 0.013540
# Episode 2870	Last length:   199	 Reward: -195.76 Max height: 0.41 Max velocity: 0.010928
# Episode 2880	Last length:   199	 Reward: -195.97 Max height: 0.39 Max velocity: 0.012231
# Episode 2890	Last length:   199	 Reward: -195.89 Max height: 0.40 Max velocity: 0.015273
# Episode 2900	Last length:   199	 Reward: -195.39 Max height: 0.45 Max velocity: 0.007491
# Episode 2910	Last length:   199	 Reward: -195.56 Max height: 0.43 Max velocity: 0.011254
# Episode 2920	Last length:   199	 Reward: -195.33 Max height: 0.46 Max velocity: 0.005040
# Episode 2930	Last length:   199	 Reward: -196.47 Max height: 0.34 Max velocity: 0.015987
# Episode 2940	Last length:   199	 Reward: -195.67 Max height: 0.42 Max velocity: 0.008179
# Episode 2950	Last length:   199	 Reward: -195.90 Max height: 0.40 Max velocity: 0.013659
# Episode 2960	Last length:   199	 Reward: -196.21 Max height: 0.37 Max velocity: 0.011334
# Episode 2970	Last length:   199	 Reward: -195.87 Max height: 0.40 Max velocity: 0.009845
# Episode 2980	Last length:   199	 Reward: -196.06 Max height: 0.38 Max velocity: 0.017944
# Episode 2990	Last length:   199	 Reward: -195.90 Max height: 0.40 Max velocity: 0.013733
# Episode 3000	Last length:   199	 Reward: -195.12 Max height: 0.48 Max velocity: 0.007479
# Episode 3010	Last length:   199	 Reward: -195.94 Max height: 0.40 Max velocity: 0.009625
# Episode 3020	Last length:   199	 Reward: -197.24 Max height: 0.25 Max velocity: 0.021728
# Episode 3030	Last length:   199	 Reward: -195.77 Max height: 0.41 Max velocity: 0.013435
# Episode 3040	Last length:   199	 Reward: -195.46 Max height: 0.45 Max velocity: 0.005913
# Episode 3050	Last length:   199	 Reward: -195.35 Max height: 0.46 Max velocity: 0.008087
# Episode 3060	Last length:   199	 Reward: -196.01 Max height: 0.39 Max velocity: 0.011770
# Episode 3070	Last length:   199	 Reward: -195.84 Max height: 0.41 Max velocity: 0.009601
# Episode 3080	Last length:   199	 Reward: -196.00 Max height: 0.39 Max velocity: 0.010725
# Episode 3090	Last length:   199	 Reward: -195.74 Max height: 0.42 Max velocity: 0.009767
# Episode 3100	Last length:   199	 Reward: -196.87 Max height: 0.29 Max velocity: 0.023508
# Episode 3110	Last length:   199	 Reward: -195.95 Max height: 0.39 Max velocity: 0.011210
# Episode 3120	Last length:   199	 Reward: -196.45 Max height: 0.34 Max velocity: 0.016546
# Episode 3130	Last length:   199	 Reward: -196.06 Max height: 0.38 Max velocity: 0.015571
# Episode 3140	Last length:   199	 Reward: -195.31 Max height: 0.46 Max velocity: 0.006759
# Episode 3150	Last length:   199	 Reward: -196.19 Max height: 0.37 Max velocity: 0.015037
# Episode 3160	Last length:   199	 Reward: -195.58 Max height: 0.43 Max velocity: 0.009116
# Episode 3170	Last length:   199	 Reward: -195.45 Max height: 0.45 Max velocity: 0.006022
# Episode 3180	Last length:   199	 Reward: -195.47 Max height: 0.44 Max velocity: 0.008025
# Episode 3190	Last length:   199	 Reward: -197.10 Max height: 0.27 Max velocity: 0.020111
# Episode 3200	Last length:   199	 Reward: -195.69 Max height: 0.42 Max velocity: 0.010836
# Episode 3210	Last length:   199	 Reward: -195.52 Max height: 0.44 Max velocity: 0.012413
# Episode 3220	Last length:   199	 Reward: -195.75 Max height: 0.42 Max velocity: 0.009407
# Episode 3230	Last length:   199	 Reward: -195.83 Max height: 0.41 Max velocity: 0.011615
# Episode 3240	Last length:   199	 Reward: -195.32 Max height: 0.46 Max velocity: 0.005850
# Episode 3250	Last length:   199	 Reward: -195.45 Max height: 0.45 Max velocity: 0.007752
# Episode 3260	Last length:   199	 Reward: -197.82 Max height: 0.19 Max velocity: 0.028067
# Episode 3270	Last length:   199	 Reward: -195.66 Max height: 0.42 Max velocity: 0.008914
# Episode 3280	Last length:   199	 Reward: -195.74 Max height: 0.42 Max velocity: 0.010783
# Episode 3290	Last length:   199	 Reward: -195.58 Max height: 0.44 Max velocity: 0.007018
# Episode 3300	Last length:   199	 Reward: -195.57 Max height: 0.43 Max velocity: 0.009559
# Episode 3310	Last length:   199	 Reward: -195.30 Max height: 0.46 Max velocity: 0.010425
# Episode 3320	Last length:   199	 Reward: -196.67 Max height: 0.31 Max velocity: 0.019718
# Episode 3330	Last length:   199	 Reward: -196.43 Max height: 0.34 Max velocity: 0.014029
# Episode 3340	Last length:   199	 Reward: -196.45 Max height: 0.34 Max velocity: 0.016420
# Episode 3350	Last length:   199	 Reward: -195.54 Max height: 0.43 Max velocity: 0.015974
# Episode 3360	Last length:   199	 Reward: -195.68 Max height: 0.42 Max velocity: 0.008187
# Episode 3370	Last length:   199	 Reward: -196.46 Max height: 0.34 Max velocity: 0.015521
# Episode 3380	Last length:   199	 Reward: -196.33 Max height: 0.35 Max velocity: 0.013634
# Episode 3390	Last length:   199	 Reward: -196.56 Max height: 0.33 Max velocity: 0.013349
# Episode 3400	Last length:   199	 Reward: -195.75 Max height: 0.41 Max velocity: 0.016164
# Episode 3410	Last length:   199	 Reward: -196.74 Max height: 0.31 Max velocity: 0.015745
# Episode 3420	Last length:   199	 Reward: -195.81 Max height: 0.41 Max velocity: 0.013119
# Episode 3430	Last length:   199	 Reward: -195.19 Max height: 0.47 Max velocity: 0.006421
# Episode 3440	Last length:   199	 Reward: -195.87 Max height: 0.40 Max velocity: 0.010969
# Episode 3450	Last length:   199	 Reward: -195.61 Max height: 0.43 Max velocity: 0.008090
# Episode 3460	Last length:   199	 Reward: -196.53 Max height: 0.33 Max velocity: 0.017957
# Episode 3470	Last length:   199	 Reward: -197.36 Max height: 0.24 Max velocity: 0.020584
# Episode 3480	Last length:   199	 Reward: -195.52 Max height: 0.44 Max velocity: 0.007181
# Episode 3490	Last length:   199	 Reward: -195.47 Max height: 0.44 Max velocity: 0.008288
# Episode 3500	Last length:   199	 Reward: -196.02 Max height: 0.38 Max velocity: 0.017843
# Episode 3510	Last length:   199	 Reward: -195.65 Max height: 0.42 Max velocity: 0.010740
# Episode 3520	Last length:   199	 Reward: -195.30 Max height: 0.46 Max velocity: 0.005992
# Episode 3530	Last length:   199	 Reward: -196.28 Max height: 0.36 Max velocity: 0.013784
# Episode 3540	Last length:   199	 Reward: -195.85 Max height: 0.40 Max velocity: 0.013315
# Episode 3550	Last length:   199	 Reward: -196.68 Max height: 0.32 Max velocity: 0.016390
# Episode 3560	Last length:   199	 Reward: -196.29 Max height: 0.35 Max velocity: 0.017745
# Episode 3570	Last length:   199	 Reward: -195.99 Max height: 0.39 Max velocity: 0.012967
# Episode 3580	Last length:   199	 Reward: -195.42 Max height: 0.45 Max velocity: 0.008138
# Episode 3590	Last length:   199	 Reward: -195.23 Max height: 0.47 Max velocity: 0.007866
# Episode 3600	Last length:   199	 Reward: -196.63 Max height: 0.31 Max velocity: 0.022423
# Episode 3610	Last length:   199	 Reward: -195.95 Max height: 0.39 Max velocity: 0.013039
# Episode 3620	Last length:   199	 Reward: -195.93 Max height: 0.39 Max velocity: 0.012037
# Episode 3630	Last length:   199	 Reward: -196.97 Max height: 0.28 Max velocity: 0.023054
# Episode 3640	Last length:   199	 Reward: -195.23 Max height: 0.47 Max velocity: 0.006950
# Episode 3650	Last length:   199	 Reward: -195.18 Max height: 0.47 Max velocity: 0.007188
# Episode 3660	Last length:   199	 Reward: -195.87 Max height: 0.40 Max velocity: 0.011512
# Episode 3670	Last length:   199	 Reward: -196.07 Max height: 0.38 Max velocity: 0.013226
# Episode 3680	Last length:   199	 Reward: -195.43 Max height: 0.45 Max velocity: 0.009173
# Episode 3690	Last length:   199	 Reward: -195.90 Max height: 0.40 Max velocity: 0.012359
# Episode 3700	Last length:   199	 Reward: -195.14 Max height: 0.48 Max velocity: 0.007387
# Episode 3710	Last length:   199	 Reward: -196.49 Max height: 0.34 Max velocity: 0.014847
# Episode 3720	Last length:   199	 Reward: -195.49 Max height: 0.44 Max velocity: 0.008475
# Episode 3730	Last length:   199	 Reward: -196.79 Max height: 0.29 Max velocity: 0.028152
# Episode 3740	Last length:   199	 Reward: -195.47 Max height: 0.45 Max velocity: 0.007892
# Episode 3750	Last length:   199	 Reward: -196.21 Max height: 0.37 Max velocity: 0.013835
# Episode 3760	Last length:   199	 Reward: -195.95 Max height: 0.39 Max velocity: 0.015306
# Episode 3770	Last length:   199	 Reward: -195.73 Max height: 0.42 Max velocity: 0.010501
# Episode 3780	Last length:   199	 Reward: -196.17 Max height: 0.37 Max velocity: 0.016521
# Episode 3790	Last length:   199	 Reward: -195.02 Max height: 0.49 Max velocity: 0.006972
# Episode 3800	Last length:   199	 Reward: -195.70 Max height: 0.42 Max velocity: 0.008681
# Episode 3810	Last length:   199	 Reward: -196.49 Max height: 0.33 Max velocity: 0.017929
# Episode 3820	Last length:   199	 Reward: -195.20 Max height: 0.47 Max velocity: 0.005392
# Episode 3830	Last length:   199	 Reward: -195.51 Max height: 0.44 Max velocity: 0.007592
# Episode 3840	Last length:   199	 Reward: -196.90 Max height: 0.29 Max velocity: 0.016278
# Episode 3850	Last length:   199	 Reward: -195.96 Max height: 0.39 Max velocity: 0.016731
# Episode 3860	Last length:   199	 Reward: -195.35 Max height: 0.46 Max velocity: 0.009355
# Episode 3870	Last length:   199	 Reward: -196.18 Max height: 0.37 Max velocity: 0.014914
# Episode 3880	Last length:   199	 Reward: -196.81 Max height: 0.30 Max velocity: 0.019190
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-bf82c8140d54> in <module>
#     114
#     115 print("threshold={} \n".format(env.spec.reward_threshold))
# --> 116 main()
#     117
#
# <ipython-input-1-bf82c8140d54> in main()
#     104         running_reward = running_reward + max_height * 10 + max_velocity * 10 # + avg_velocity * 10
#     105
# --> 106         finish_episode()
#     107         if i_episode % args['log_interval'] == 0:
#     108             print('Episode {}\tLast length: {:5d}\t Reward: {:.2f} Max height: {:.2f} Max velocity: {:.6f}'.format(
#
# <ipython-input-1-bf82c8140d54> in finish_episode()
#      71     for (log_prob, value), r in zip(saved_actions, rewards):
#      72         reward = r - value.item()
# ---> 73         policy_losses.append(-log_prob * reward)
#      74         value_losses.append(F.smooth_l1_loss(value, torch.tensor([r])))
#      75     optimizer.zero_grad()
#
# KeyboardInterrupt:

# %%
print(env.spec.reward_threshold)
