# %%
import numpy as np
import matplotlib.pyplot as plt
import gym
import random

# %matplotlib inline

# %%
env = gym.make('FrozenLake-v0')

MAX_STEPS = env.spec.timestep_limit # maximum steps in an episode, 200 for Taxi-v2

NUM_EPISODES = 1000000
GAMMA = 0.95  # Discount factor from Bellman Equation
START_ALPHA = 0.3  # Learning rate, how much we update our Q table each step
ALPHA_TAPER = 0.0001 # How much our adaptive learning rate is adjusted each update
START_EPSILON = 1.0  # Probability of random action
EPSILON_TAPER = 0.0001 # How much epsilon is adjusted each step

render = False

# %%
def update_Q(Q, update_counts, alpha, prev_state, action, reward, cur_state):      
    
    return Q, update

def moving_average(values, n=100) :
    ret = np.cumsum(values, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n

# %%
def epsilon_action(Q, s, eps=0.1):
    if random.random() < (1 - eps):
        return np.argmax(Q[s])
    else:
        return env.action_space.sample()

# %%
def main():
    
    obs_dim = env.observation_space.n # size of our state
    action_dim = env.action_space.n # number of actions

    # Initialize our Q table
    Q = np.zeros((obs_dim, action_dim))

    state_visit_counts = {}
    update_counts = np.zeros((obs_dim, action_dim), dtype=np.dtype(int))
    
    rewards_list = []    
    deltas = []
              
    for i_episode in range(NUM_EPISODES): 
        
        eps = START_EPSILON / (1.0 + i_episode * EPSILON_TAPER)
        
        # Play episode
        biggest_change = 0
        reward_per_episode = 0 
        curr_state = env.reset()
        for step in range(MAX_STEPS):
            prev_state = curr_state
            state_visit_counts[prev_state] = state_visit_counts.get(prev_state,0) + 1
            action = epsilon_action(Q, curr_state, eps)           
            curr_state, reward, done, info = env.step(action)
            reward_per_episode += reward
            old_qsa = Q[prev_state][action]
            
            # Update Q
            alpha = START_ALPHA / (1.0 + update_counts[prev_state][action] * ALPHA_TAPER)
            update_counts[prev_state][action] += 1
            Q[prev_state][action] += alpha * (reward + GAMMA * max(Q[curr_state]) - Q[prev_state][action])
            
            #Q = update_Q(Q, alpha, prev_state, action, reward, curr_state)
            biggest_change = max(biggest_change, np.abs(old_qsa - Q[prev_state][action]))
            if done:
                break
        rewards_list.append(reward_per_episode)
        deltas.append(biggest_change)               
            
        avg_reward = np.mean(rewards_list[-500:])     
        if i_episode % 5000 == 0:            
            avg_delta = np.mean(deltas[-500:])  
            print ("Episode: {}   Avg reward: {:3.3f}  Avg Delta: {:8.8f}  Epsilon: {:3.3f}  Alpha: {:6.6f}".format(
                i_episode, avg_reward, avg_delta, eps, alpha))
            
            
        #if len(rewards_list) > 1000:
        #    rewards_list.pop(0)
          
        if avg_reward >= env.spec.reward_threshold: 
            print("########## Solved! ###########")
            break
            
  
    mean_state_visits = np.mean(list(state_visit_counts.values()))
    print("each state was visited on average: ", mean_state_visits, " times.\n")
  

    plt.plot(moving_average(deltas, n=1000))
    plt.show()
    
    plt.plot(moving_average(rewards_list, n=1000))
    plt.show()
    
    return Q
  
            
print("action_space={}".format(env.action_space))
# Episode: 915000   Avg reward: 0.672  Avg Delta: 0.00283990  Epsilon: 0.011  Alpha: 0.001924
# Episode: 920000   Avg reward: 0.690  Avg Delta: 0.00301255  Epsilon: 0.011  Alpha: 0.001912
# Episode: 925000   Avg reward: 0.706  Avg Delta: 0.00304278  Epsilon: 0.011  Alpha: 0.006523
# Episode: 930000   Avg reward: 0.692  Avg Delta: 0.00311730  Epsilon: 0.011  Alpha: 0.001887
# Episode: 935000   Avg reward: 0.656  Avg Delta: 0.00208700  Epsilon: 0.011  Alpha: 0.001875
# Episode: 940000   Avg reward: 0.692  Avg Delta: 0.00293854  Epsilon: 0.011  Alpha: 0.001863
# Episode: 945000   Avg reward: 0.682  Avg Delta: 0.00298877  Epsilon: 0.010  Alpha: 0.006363
# Episode: 950000   Avg reward: 0.666  Avg Delta: 0.00334636  Epsilon: 0.010  Alpha: 0.006323
# Episode: 955000   Avg reward: 0.690  Avg Delta: 0.00252251  Epsilon: 0.010  Alpha: 0.001829
# Episode: 960000   Avg reward: 0.682  Avg Delta: 0.00294551  Epsilon: 0.010  Alpha: 0.006248
# Episode: 965000   Avg reward: 0.690  Avg Delta: 0.00346250  Epsilon: 0.010  Alpha: 0.053744
# Episode: 970000   Avg reward: 0.730  Avg Delta: 0.00328404  Epsilon: 0.010  Alpha: 0.006173
# Episode: 975000   Avg reward: 0.688  Avg Delta: 0.00270112  Epsilon: 0.010  Alpha: 0.006137
# Episode: 980000   Avg reward: 0.664  Avg Delta: 0.00268523  Epsilon: 0.010  Alpha: 0.006098
# Episode: 985000   Avg reward: 0.688  Avg Delta: 0.00360946  Epsilon: 0.010  Alpha: 0.006063
# Episode: 990000   Avg reward: 0.712  Avg Delta: 0.00262891  Epsilon: 0.010  Alpha: 0.001753
# Episode: 995000   Avg reward: 0.708  Avg Delta: 0.00253536  Epsilon: 0.010  Alpha: 0.001742
# each state was visited on average:  3251992.272727273  times.
# Final Q values: [[0.17968199 0.16979299 0.16963644 0.16389558]
#  [0.12558553 0.09268076 0.08751727 0.15432979]
#  [0.15047915 0.14744268 0.14469236 0.1377872 ]
#  [0.0918626  0.09803041 0.05101999 0.13196427]
#  [0.20786165 0.13761841 0.11743004 0.12440861]
#  [0.         0.         0.         0.        ]
#  [0.15986379 0.05780382 0.15388716 0.0338213 ]
#  [0.         0.         0.         0.        ]
#  [0.16528192 0.22146511 0.19688832 0.26951955]
#  [0.27084973 0.36960047 0.2513407  0.24457539]
#  [0.39834052 0.36416111 0.21915715 0.18766675]
#  [0.         0.         0.         0.        ]
#  [0.         0.         0.         0.        ]
#  [0.32463971 0.38060246 0.5065545  0.36861772]
#  [0.47869093 0.72346276 0.71316908 0.57061559]
#  [0.         0.         0.         0.        ]]

# %%
def test(Q):            
    state = env.reset()
    for step in range(MAX_STEPS):        
        action = epsilon_action(Q, state, 0)          
        state, reward, done, _ = env.step(action) 
        env.render()                           
        if done:
            print("Reward: {}".format(reward))
            break

test(Q_final)
# Out:
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Reward: 1.0
