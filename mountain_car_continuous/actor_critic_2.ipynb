# %%
import argparse
import gym
import numpy as np
from itertools import count
from collections import namedtuple

from DDPG.ddpg import DDPG

args = {
    'render': True,
    'log_interval': 1
}

env = gym.make('MountainCarContinuous-v0')
episodes = 10000
reward_history = []


def main():   
    task = {
        'state_size': 2,
        'action_size': 1,
        'action_high': 1,
        'action_low': 0
    }
    agent = DDPG(task)    
    for i_episode in range(episodes):
        running_reward = 0     
        state = env.reset()
        for t in range(10000):  # Don't infinite loop while learning
            action, noise_coeff = agent.act(state, i_episode)            
            state, reward, done, _ = env.step(action)      
            agent.step(action, reward, state, done)
            if args['render']:
                env.render()                   
            running_reward += reward            
            if done:
                break
        
        reward_history.append(running_reward)
        
        if i_episode % args['log_interval'] == 0:
            avg_reward = np.mean(reward_history[-100:])  
            print('Episode {}   Last length: {:5d}   Reward: {:7.2f}   Avg Reward: {:7.2f}   Noise: {:.2f}'.format(
                i_episode, t, running_reward, avg_reward, noise_coeff))
        if avg_reward > env.spec.reward_threshold and i_episode > 100:
            print("Solved! Average 100-episode reward is now {}!".format(avg_reward))
            break

print("action_space={}".format(env.action_space))
print("obs_space={}".format(env.observation_space))
print("threshold={} \n".format(env.spec.reward_threshold))
main()
# Out:
# Using TensorFlow backend.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# action_space=Box(1,)
# obs_space=Box(2,)
# threshold=90.0
#
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# Episode 0   Last length:   283   Reward:   87.99   Avg Reward:   87.99   Noise: 1.00
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# STATE=(1, 2) <class 'numpy.ndarray'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-0c9af181ba7a> in <module>
#      51 print("obs_space={}".format(env.observation_space))
#      52 print("threshold={} \n".format(env.spec.reward_threshold))
# ---> 53 main()
#      54
#
# <ipython-input-1-0c9af181ba7a> in main()
#      31             action, noise_coeff = agent.act(state, i_episode)
#      32             state, reward, done, _ = env.step(action)
# ---> 33             agent.step(action, reward, state, done)
#      34             if args['render']:
#      35                 env.render()
#
# ~/PycharmProjects/gym/mountain_car_continuous/DDPG/ddpg.py in step(self, action, reward, next_state, done)
#      58         if len(self.memory) > self.batch_size:
#      59             experiences = self.memory.sample()
# ---> 60             self.learn(experiences)
#      61
#      62         # Roll over last state and action
#
# ~/PycharmProjects/gym/mountain_car_continuous/DDPG/ddpg.py in learn(self, experiences)
#      93         # Compute Q targets for current states and train critic model (local)
#      94         Q_targets = rewards + self.gamma * Q_targets_next * (1 - dones)
# ---> 95         self.critic_local.model.train_on_batch(x=[states, actions], y=Q_targets)
#      96
#      97         # Train actor model (local)
#
# ~/.conda/envs/reinforcement/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# ~/.conda/envs/reinforcement/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/.conda/envs/reinforcement/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/.conda/envs/reinforcement/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
